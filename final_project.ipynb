# %% [markdown]
# # Import Libraries and Load Data

# %%
import pandas as pd
import json
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import SnowballStemmer # Includes support for different sets of stop words and tokenizers that are better suited for languages other than English
import string
from langdetect import detect, LangDetectException # To detect different languages
# Another approach could be to use a public API to translate the content from any word to english and to conduct the whole process in english
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from tqdm import tqdm

# %%
# Download NLTK resources
nltk.download('punkt')
# nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /Users/yuyi/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/yuyi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# # Preprocessing

# %%
# Languages supported by both SnowballStemmer and Word_tokenize; Otherwise it will give error
lang_map = {
    'en': 'english',        # English
    'es': 'spanish',        # Spanish
	'fr': 'french',         # French
    'de': 'german',         # German
    'da': 'danish',         # Danish
	'nl': 'dutch',          # Dutch
	'it': 'italian',        # Italian
    'fi': 'finnish',        # Finnish
    'ru': 'russian',        # Russian
	'el': 'greek',          # Greek
	'no': 'norwegian',      # Norwegian
	'pt': 'portuguese',     # Portuguese
	'sv': 'swedish'        # Swedish
}

# %%
def preprocess_text(text, lang_code='en', language_mapping=lang_map):
    # Map language code to SnowballStemmer language name
    language = language_mapping.get(lang_code, 'english')  # Default to 'english' if lang_code is unsupported
    
    text = text.lower()

    tokens = word_tokenize(text, language=language)
    
    # Remove punctuation
    table = str.maketrans('', '', string.punctuation)
    stripped_tokens = [w.translate(table) for w in tokens]
    
    # Remove non-alphabetic tokens
    words = [word for word in stripped_tokens if word.isalpha()]

    #TODO: remove what comes after an @; it will make the content look strange after translation
    
    # Remove stop words for the detected language
    try:
        stop_words = set(stopwords.words(language))
    except OSError:
        stop_words = set()
    words = [w for w in words if not w in stop_words]
    
    # Stemming
    try:
        stemmer = SnowballStemmer(language)
        stemmed = [stemmer.stem(word) for word in words]
    except Exception as e:
        print(f"Stemming not performed due to: {e}")
        stemmed = words  # Fallback to non-stemmed words if stemming fails

    return stemmed

# %%
def process_tweets(json_file):
    processed_tweets = []

    with open(json_file, 'r') as file:
        total_lines = sum(1 for line in file)

    # Open the file and read it line by line
    with open(json_file, 'r') as file:
        # i = 0
        for line in tqdm(file, total=total_lines, desc="Processing Tweets", unit="tweet"):
            try:
                tweet = json.loads(line)
                
                # Attempt to detect language
                try:
                    lang = detect(tweet.get('content', ''))
                except LangDetectException:
                    lang = 'unsure'  # Set to 'unsure' if language detection fails

                # print(lang, tweet)

                lang_of_process = 'english' if lang == 'unsure' else lang # Use English as the default language if unsure

                # Process the tweet content
                content = tweet.get('content', '')
                processed_content = preprocess_text(content, lang_code=lang_of_process)
                
                # Extract hashtags and handle them separately if needed
                hashtags = [word for word in content.split() if word.startswith('#')] #TODO: See what can we do with hashtags
                
                # Build the processed tweet information
                processed_tweet = {
                    'id': tweet.get('id', None),
                    'content': ' '.join(processed_content),
                    'date': tweet.get('date'),
                    'hashtags': ' '.join(hashtags),
                    'likes': tweet.get('likeCount'),
                    'retweets': tweet.get('retweetCount'),
                    'url': tweet.get('url'),
                    'language': lang  # Store the detected or default language
                }
                
                processed_tweets.append(processed_tweet)
                # i += 1
                # if i > 50:  # Limit to 10 tweets for demonstration
                #     break
            except json.JSONDecodeError:
                print(f"Failed to parse line: {line}")
                continue

    return processed_tweets

# %%
# Correct path to your JSON file
json_file_path = './data/farmers-protest-tweets.json'
processed_data = process_tweets(json_file_path)
# Out:
# Processing Tweets: 100%|██████████| 117405/117405 [09:57<00:00, 196.34tweet/s]

# %%
print(processed_data[:10])
# Out:
# [{'id': 1364506195453767680, 'content': 'ਆ ਚ farmersprotest', 'date': '2021-02-24T09:23:22+00:00', 'hashtags': '#FarmersProtest', 'likes': 0, 'retweets': 0, 'url': 'https://twitter.com/parmarmaninder/status/1364506195453767680', 'language': 'pa'}, {'id': 1364506167226032128, 'content': 'reallyswara rohinisgh watch full video https farmersprotest nofarmersnofood https tcofustokocxk', 'date': '2021-02-24T09:23:16+00:00', 'hashtags': '#farmersprotest #NoFarmersNoFood', 'likes': 0, 'retweets': 0, 'url': 'https://twitter.com/anmoldhaliwal/status/1364506167226032128', 'language': 'en'}, {'id': 1364506144002088963, 'content': 'kisanektamorcha farmersprotest nofarmersnofood https', 'date': '2021-02-24T09:23:10+00:00', 'hashtags': '#KisanEktaMorcha #FarmersProtest #NoFarmersNoFood', 'likes': 0, 'retweets': 0, 'url': 'https://twitter.com/KotiaPreet/status/1364506144002088963', 'language': 'en'}, {'id': 1364506120497360896, 'content': 'jai jwaan jai kissan farmersprotest modiignoringfarmersdeath https', 'date': '2021-02-24T09:23:05+00:00', 'hashtags': '#FarmersProtest #ModiIgnoringFarmersDeaths', 'likes': 0, 'retweets': 0, 'url': 'https://twitter.com/babli_708/status/1364506120497360896', 'language': 'en'}, {'id': 1364506076272496640, 'content': 'farmersprotest', 'date': '2021-02-24T09:22:54+00:00', 'hashtags': '#FarmersProtest', 'likes': 0, 'retweets': 0, 'url': 'https://twitter.com/Varinde17354019/status/1364506076272496640', 'language': 'en'}, {'id': 1364505995859423234, 'content': 'modidontsellfarm farmersprotest https', 'date': '2021-02-24T09:22:35+00:00', 'hashtags': '#ModiDontSellFarmers #FarmersProtest', 'likes': 0, 'retweets': 0, 'url': 'https://twitter.com/BitnamSingh/status/1364505995859423234', 'language': 'en'}, {'id': 1364505991887347714, 'content': 'watch full video https farmersprotest nofarmersnofood https', 'date': '2021-02-24T09:22:34+00:00', 'hashtags': '#farmersprotest #NoFarmersNoFood', 'likes': 0, 'retweets': 0, 'url': 'https://twitter.com/anmoldhaliwal/status/1364505991887347714', 'language': 'en'}, {'id': 1364505896576053248, 'content': 'farmersprot https', 'date': '2021-02-24T09:22:11+00:00', 'hashtags': '#FarmersProtest', 'likes': 0, 'retweets': 0, 'url': 'https://twitter.com/SatThiara/status/1364505896576053248', 'language': 'de'}, {'id': 1364505892612268032, 'content': 'wheatfield farmersprotest https tcoyxsvdprpgg', 'date': '2021-02-24T09:22:10+00:00', 'hashtags': '#WheatField #FarmersProtest', 'likes': 1, 'retweets': 1, 'url': 'https://twitter.com/PasumaiVikatan/status/1364505892612268032', 'language': 'ta'}, {'id': 1364505813834989568, 'content': 'watch full video https farmersprotest nofarmersnofood https', 'date': '2021-02-24T09:21:51+00:00', 'hashtags': '#farmersprotest #NoFarmersNoFood', 'likes': 0, 'retweets': 0, 'url': 'https://twitter.com/anmoldhaliwal/status/1364505813834989568', 'language': 'en'}]

# %%
# Map tweetId with documentId
df = pd.DataFrame(processed_data)
doc_mapping = pd.read_csv('./data/tweet_document_ids_map.csv') 

# Merge the processed tweets DataFrame with the document mapping on the 'id' column
df_merged = pd.merge(df, doc_mapping, on='id', how='left')
df_merged.head()
# Out:
#                     id                                            content  \
# 0  1364506195453767680                                 ਆ ਚ farmersprotest
# 1  1364506167226032128  reallyswara rohinisgh watch full video https f...
# 2  1364506144002088963  kisanektamorcha farmersprotest nofarmersnofood...
# 3  1364506120497360896  jai jwaan jai kissan farmersprotest modiignori...
# 4  1364506076272496640                                     farmersprotest
#
#                         date  \
# 0  2021-02-24T09:23:22+00:00
# 1  2021-02-24T09:23:16+00:00
# 2  2021-02-24T09:23:10+00:00
# 3  2021-02-24T09:23:05+00:00
# 4  2021-02-24T09:22:54+00:00
#
#                                             hashtags  likes  retweets  \
# 0                                    #FarmersProtest      0         0
# 1                   #farmersprotest #NoFarmersNoFood      0         0
# 2  #KisanEktaMorcha #FarmersProtest #NoFarmersNoFood      0         0
# 3         #FarmersProtest #ModiIgnoringFarmersDeaths      0         0
# 4                                    #FarmersProtest      0         0
#
#                                                  url language  docId
# 0  https://twitter.com/parmarmaninder/status/1364...       pa    NaN
# 1  https://twitter.com/anmoldhaliwal/status/13645...       en  doc_2
# 2  https://twitter.com/KotiaPreet/status/13645061...       en    NaN
# 3  https://twitter.com/babli_708/status/136450612...       en    NaN
# 4  https://twitter.com/Varinde17354019/status/136...       en    NaN

# %%
# Save the data in CSV format
df_merged.to_csv('processed_data.csv', index=False)

# %% [markdown]
# # Explanatory Data Analysis

# %%
df = pd.read_csv("./processed_data.csv")

df.head(20)
# TODO: Ask if all tweets are by default related with a document or can it be null
# Out:
#                      id                                            content  \
# 0   1364506195453767680                                 ਆ ਚ farmersprotest
# 1   1364506167226032128  reallyswara rohinisgh watch full video https f...
# 2   1364506144002088963  kisanektamorcha farmersprotest nofarmersnofood...
# 3   1364506120497360896  jai jwaan jai kissan farmersprotest modiignori...
# 4   1364506076272496640                                     farmersprotest
# 5   1364505995859423234              modidontsellfarm farmersprotest https
# 6   1364505991887347714  watch full video https farmersprotest nofarmer...
# 7   1364505896576053248                                  farmersprot https
# 8   1364505892612268032      wheatfield farmersprotest https tcoyxsvdprpgg
# 9   1364505813834989568  watch full video https farmersprotest nofarmer...
# 10  1364505749359976448  anoth farmer malkeet singh mahilpur hoshiarpur...
# 11  1364505737695739906   jai kissan farmersprotest modidontsellfarm https
# 12  1364505706804744192                    farmersprot https tcoiighgzkfcx
# 13  1364505702715154439              farmersprotest modidontsellfarm https
# 14  1364505676375076867  akshaykumar hi tell boss modidontsellfarm than...
# 15  1364505591641735170  modidontsellfarmer farmersprotest https tcorbl...
# 16  1364505511073300481  taapse watch full video farmersprotest nofarme...
# 17  1364505462419447810                                  farmersprot https
# 18  1364505452134817795  despit increas tax petroldiesel must increas t...
# 19  1364505444606119940                            आज कल कर farmersprotest
#
#                          date  \
# 0   2021-02-24T09:23:22+00:00
# 1   2021-02-24T09:23:16+00:00
# 2   2021-02-24T09:23:10+00:00
# 3   2021-02-24T09:23:05+00:00
# 4   2021-02-24T09:22:54+00:00
# 5   2021-02-24T09:22:35+00:00
# 6   2021-02-24T09:22:34+00:00
# 7   2021-02-24T09:22:11+00:00
# 8   2021-02-24T09:22:10+00:00
# 9   2021-02-24T09:21:51+00:00
# 10  2021-02-24T09:21:36+00:00
# 11  2021-02-24T09:21:33+00:00
# 12  2021-02-24T09:21:26+00:00
# 13  2021-02-24T09:21:25+00:00
# 14  2021-02-24T09:21:19+00:00
# 15  2021-02-24T09:20:58+00:00
# 16  2021-02-24T09:20:39+00:00
# 17  2021-02-24T09:20:28+00:00
# 18  2021-02-24T09:20:25+00:00
# 19  2021-02-24T09:20:23+00:00
#
#                                              hashtags  likes  retweets  \
# 0                                     #FarmersProtest      0         0
# 1                    #farmersprotest #NoFarmersNoFood      0         0
# 2   #KisanEktaMorcha #FarmersProtest #NoFarmersNoFood      0         0
# 3          #FarmersProtest #ModiIgnoringFarmersDeaths      0         0
# 4                                     #FarmersProtest      0         0
# 5                #ModiDontSellFarmers #FarmersProtest      0         0
# 6                    #farmersprotest #NoFarmersNoFood      0         0
# 7                                     #FarmersProtest      0         0
# 8                         #WheatField #FarmersProtest      1         1
# 9                    #farmersprotest #NoFarmersNoFood      0         0
# 10                                    #FarmersProtest      3         3
# 11               #FarmersProtest #ModiDontSellFarmers      0         0
# 12                                    #FarmersProtest      0         0
# 13               #FarmersProtest #ModiDontSellFarmers      0         0
# 14               #ModiDontSellFarmers #FarmersProtest      0         0
# 15               #ModiDontSellFarmers #farmersprotest      0         0
# 16                   #farmersprotest #NoFarmersNoFood      0         0
# 17                                    #FarmersProtest      0         0
# 18  #taxes #petrolDiesel #taxes #alcohol #cigarett...      1         1
# 19                                    #FarmersProtest      0         0
#
#                                                   url language  docId
# 0   https://twitter.com/parmarmaninder/status/1364...       pa    NaN
# 1   https://twitter.com/anmoldhaliwal/status/13645...       en  doc_2
# 2   https://twitter.com/KotiaPreet/status/13645061...       en    NaN
# 3   https://twitter.com/babli_708/status/136450612...       en    NaN
# 4   https://twitter.com/Varinde17354019/status/136...       en    NaN
# 5   https://twitter.com/BitnamSingh/status/1364505...       en    NaN
# 6   https://twitter.com/anmoldhaliwal/status/13645...       en  doc_3
# 7   https://twitter.com/SatThiara/status/136450589...       de    NaN
# 8   https://twitter.com/PasumaiVikatan/status/1364...       ta    NaN
# 9   https://twitter.com/anmoldhaliwal/status/13645...       en  doc_4
# 10  https://twitter.com/ShariaActivist/status/1364...       en  doc_5
# 11  https://twitter.com/babli_708/status/136450573...       en    NaN
# 12  https://twitter.com/Dallehal/status/1364505706...       de    NaN
# 13  https://twitter.com/KaurAma57668156/status/136...       pa    NaN
# 14  https://twitter.com/KaurDosanjh1979/status/136...       en  doc_6
# 15  https://twitter.com/ArjunSinghPanam/status/136...       sv    NaN
# 16  https://twitter.com/anmoldhaliwal/status/13645...       en  doc_7
# 17  https://twitter.com/BitnamSingh/status/1364505...       de    NaN
# 18  https://twitter.com/Satende09192805/status/136...       en  doc_8
# 19  https://twitter.com/rajraka/status/13645054446...       hi    NaN
